# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio
#
# ## Stanley Yee, Business Analyst

# %% [markdown]
# <i> I am interested in data science because i want integrate the strength of AI with the needs of business to provide effective solutions and offer insights into problem that an organisation must solve or find underlying trends to find new potential discoveries. <i>

# %% [markdown]
# ### The following code will perform calculation in addition.

# %%
number_1 = int(input('Enter your first number: '))
number_2 = int(input('Enter your second number: '))

print('{} + {} = '.format(number_1, number_2))
print(number_1 + number_2)
# Out:
# Enter your first number: 50
# Enter your second number: 50
# 50 + 50 =
# 100

# %% [markdown]
# **Sample of Codes**
# - Code for bullets: dash(-) sign with a space after it
# - Code for strikethrough: ~~string~~, symbol ~~ string ~~
# ********************************************************************************************
# - Code for Horizontal lines: ***
